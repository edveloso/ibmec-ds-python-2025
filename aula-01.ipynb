# %%
# !Pip install pandas
import pandas as pd

data = pd.read_csv('Average_Salary_by_Job_Classification.csv', encoding='utf-8')

data
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#                          Position Title  Position Class Code Grade  \
# 0         Information Technology Expert                  550    32
# 1                 Accountant/Auditor II                  210    21
# 2                  Veterinary Assistant               206513    15
# 3                           Police Aide                 3506    15
# 4       ERP Functional Business Analyst               100546    30
# ..                                  ...                  ...   ...
# 316  Correctional Supervisor - Sergeant                 3234    C6
# 317                      Police Captain                 3063    A3
# 318                  Deputy Sheriff III                 3529    G4
# 319                         Manager III                  112    M3
# 320          Correctional Specialist IV                 3247    25
#
#     Average of Base Salary  Number of Employees
# 0              $146,925.34                    9
# 1               $82,742.44                    2
# 2               $45,925.44                    2
# 3               $58,628.63                   15
# 4              $133,797.25                    3
# ..                     ...                  ...
# 316             $94,434.43                   37
# 317            $156,780.64                   21
# 318             $83,677.86                   66
# 319            $132,146.03                  252
# 320            $105,117.90                    4
#
# [321 rows x 5 columns]

# %%
# !Pip install data-profiling==4.0.0
from ydata_profiling import ProfileReport
profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)
# Out:
# ERROR: Ignored the following versions that require a different python version: 4.0.0 Requires-Python >=3.7,<3.11; 4.1.0 Requires-Python >=3.7,<3.12; 4.1.1 Requires-Python >=3.7,<3.12; 4.1.2 Requires-Python >=3.7,<3.12; 4.10.0 Requires-Python >=3.7,<3.13; 4.11.0 Requires-Python >=3.7,<3.13; 4.12.0 Requires-Python >=3.7,<3.13; 4.12.1 Requires-Python >=3.7,<3.13; 4.12.2 Requires-Python >=3.7,<3.13; 4.13.0 Requires-Python >=3.7,<3.13; 4.14.0 Requires-Python >=3.7,<3.13; 4.15.0 Requires-Python >=3.7,<3.13; 4.15.1 Requires-Python >=3.7,<3.13; 4.16.0 Requires-Python >=3.7,<3.13; 4.16.1 Requires-Python >=3.7,<3.13; 4.2.0 Requires-Python >=3.7,<3.12; 4.3.0 Requires-Python >=3.7,<3.12; 4.3.1 Requires-Python >=3.7,<3.12; 4.3.2 Requires-Python >=3.7,<3.12; 4.4.0 Requires-Python >=3.7,<3.12; 4.5.0 Requires-Python >=3.7,<3.12; 4.5.1 Requires-Python >=3.7,<3.12; 4.6.0 Requires-Python >=3.7,<3.12; 4.6.1 Requires-Python >=3.7,<3.12; 4.6.2 Requires-Python >=3.7,<3.12; 4.6.3 Requires-Python >=3.7,<3.12; 4.6.4 Requires-Python >=3.7,<3.12; 4.6.5 Requires-Python >=3.7,<3.12; 4.7.0 Requires-Python >=3.7,<3.13; 4.8.3 Requires-Python >=3.7,<3.13; 4.9.0 Requires-Python >=3.7,<3.13
# ERROR: Could not find a version that satisfies the requirement ydata-profiling==4.0.0 (from versions: none)
# ERROR: No matching distribution found for ydata-profiling==4.0.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 get_ipython().system('Pip install ydata-profiling==4.0.0')
# ----> 2 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(data, title="Pandas Profiling Report", explorative=True)
#
# ModuleNotFoundError: No module named 'ydata_profiling'
